# %%
from Match_Functions import *

# %%
#concat
df = csec_process('tb2008.xlsx', 'tb2009.xlsx', 'tb2010.xlsx', 'tb2011.xlsx', 'tb2012.xlsx', 'tb2013.xlsx')
df
# Out:
#        FIRST_NAME MIDDLE_NAME  LAST_NAME SEX DATE_OF_BIRTH  \
# 0          AADEEN    PETAGAYE      SMITH   F       18Jun92
# 1         AADRENE                  BROWN   F       23Jul90
# 2         AADRIEN        SEAN  MCDERMOTT   M       29Oct90
# 3        AADRONIE                 INGRAM   M       02May92
# 4           AAGEL           A   MARSHALL   F       10Mar96
# ...           ...         ...        ...  ..           ...
# 388471     ZWARDE           K      LOGAN   F       27Jul87
# 388472      ZWELI                   REID   M       20Apr95
# 388473      ZWELI      KHALIL       REID   M       20Apr95
# 388474      ZYANE           M  BLACKWOOD   M       01May90
# 388475      ZYANE           M  BLACKWOOD   M       05Jan90
#
#                      IDENTIFIER1                   IDENTIFIER2  \
# 0            AADEENSMITH18Jun92F   AADEENPETAGAYESMITH18Jun92F
# 1           AADRENEBROWN23Jul90F          AADRENEBROWN23Jul90F
# 2       AADRIENMCDERMOTT29Oct90M  AADRIENSEANMCDERMOTT29Oct90M
# ...

# %%
#match
matched_df = match_gast_and_csec("GSAT_2007.xlsx", df)
matched_df
# Out:
#       EXAMID  PERIODID      CANDID     FNAME  SURNAME MNAME SCHOOLID  \
# 0       GSAT    2007.0  51985013.0    KRISTI  CHARLES     E    02427
# 1       GSAT    2007.0  74234837.0   ROMARIO    WHITE     M    02256
# 2       GSAT    2007.0  38466328.0    RACHEL     CHIN     L    02439
# 3       GSAT    2007.0  65836119.0  ASHLEIGH   YEATES     S    08406
# 4       GSAT    2007.0  94102931.0   ROMARIO  MAXWELL     A    02049
# ...      ...       ...         ...       ...      ...   ...      ...
# 26300   GSAT    2007.0  59335166.0   SHANEKE   PARRIS     R    12038
# 26301   GSAT    2007.0  36956262.0    OSHANE  STEWART     O    12005
# 26302   GSAT    2007.0  14728164.0    HOWARD   NELSON     R    05028
# 26303   GSAT    2007.0  29306179.0   CARLTON    LOGAN     J    12057
# 26304   GSAT    2007.0  24538409.0   ROSHANE  WALTERS     O    12057
#
#                                     SCHOOLN GENDER         DOB  ...  \
# 0         SAINTS PETER AND PAUL PREPARATORY      F  13/02/1996  ...
# ...
